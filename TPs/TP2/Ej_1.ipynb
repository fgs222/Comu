# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Parte A

# %% [markdown]
# $$
# \left\{
#     \begin{array}\\
#         A_{max} = A_c + A_m = A_c~.~(1 + m)~~;~~m = \frac{A_m}{A_c} \\
#         A_{min} = A_c - A_m \\
#     \end{array}
# \right.
# $$

# %% [markdown]
# $$
# 5~V = A_c - A_m~~\to~~A_m = A_c - 5~V
# $$
#
# $$
# 35~V = A_c + A_c - 5~V~~\to~~40~V = 2~.~A_c
# $$

# %% [markdown]
# $$
# A_c = 20~V~~~~~~A_m = 15~V~~~~~~m = 0,75
# $$

# %% [markdown]
# $$
# A_{BL} = \frac{A_m}{2} = 7,5~V
# $$

# %% [markdown]
# ### Parte B

# %% [markdown]
# $$
# S(t) = A_c~.~(1 + m)~.~cos~(\omega_c~.~t)
# $$

# %% [markdown]
# $$
# S(t) = 20~V~.~(1 + 0,75)~.~cos~(2\pi~.~1,3~MHz~.~t)
# $$

# %% [markdown]
# ### Parte C

# %% [markdown]
# $$
# P_t = P_c + P_{BLI} + P_{BLS} = P_C + 2~.~P_{BL}
# $$

# %% [markdown]
# $$
# P_c = \frac{A^2_c}{2R} = \frac{(20~V)^2}{2~.~50~\Omega}~~\to~~P_c = 4~W
# $$

# %% [markdown]
# $$
# P_{BL} = \frac{(\frac{A_c~.~m}{2})^2}{2R} = \frac{(\frac{20~V~.~0,75}{2})^2}{2~.~50~\Omega}~~\to~~P_{BL} = 0,075~W
# $$

# %% [markdown]
# $$
# P_{t~[W]} = 4~W + 2~.~0,075~W~~\to~~P_{t~[W]} = 4,15~W
# $$

# %% [markdown]
# $$
# P_{t~[dB]} = 20~.~log(4,15~W)~~\to~~P_{t~[dB]} = 12,36~dB
# $$

# %% [markdown]
# $$
# P_{t~[dBm]} = 10~.~log(\frac{4,15~W}{1~mW})~~\to~~P_{t~[dBm]} = 36,18~dBm
# $$

# %% [markdown]
# ### Parte D

# %% [markdown]
# $$
# P_c = \frac{A^2_c}{2R} = 4~W
# $$

# %% [markdown]
# $$
# P_{c~[dBW]} = 10~.~log(\frac{4~W}{1~W})~~\to~~P_{c~[dBW]} = 6,02~dBW
# $$

# %% [markdown]
# $$
# P_{c~[dBm]} = 10~.~log(\frac{4,~W}{1~mW})~~\to~~P_{c~[dBm]} = 36,02~dBm
# $$

# %% [markdown]
# $$
# P_{BL} = \frac{(\frac{A_c~.~m}{2})^2}{2R}~~\to~~P_{BL} = 0,075~W
# $$

# %% [markdown]
# $$
# P_{BL~[dBW]} = 10~.~log(\frac{0,075~W}{1~W})~~\to~~P_{BL~[dBW]} = -11,25~dBW
# $$

# %% [markdown]
# $$
# P_{BL~[dBm]} = 10~.~log(\frac{0,075~W}{1~mW})~~\to~~P_{BL~[dBm]} = 18,75~dBW
# $$

# %% [markdown]
# ### Parte E

# %% [markdown]
# $$
# 10^{\frac{30~dB}{10}} = 1000 ~~\to~~P'_c = \frac{P_c}{1000} = 4~mW
# $$

# %% [markdown]
# $$
# P_t = P'_c + 2~.~P_{BL} = 4~mW + 2~.~0,075~~\to~~P_t = 0,154~W
# $$

# %% [markdown]
# ### Parte F

# %% [markdown]
# $$
# x'(t): 3~V_{pp}~~\to~~V_p = 1,5~V
# $$

# %% [markdown]
# $$
# A_m = G_m~.~V_p~~\to~~G_m = \frac{15~V}{2~V} = 7,5
# $$

# %% [markdown]
# $$
# A'_m = G_m~.~V_p = 7,5~.~1,5~V~~\to~~A'_m = 11,25~V
# $$

# %% [markdown]
# $$
# m' = \frac{A_m}{A_c} = \frac{11,25~V}{20~V}~~\to~~m' = 0,5625
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Parte G

# %% [markdown]
# $$
# m = \frac{A_m}{A_c} = 90~\%~~\to~~A_m = 0,95~.~A_c = 0,95~.~20~V~~\to~~A_m = 19~V
# $$

# %% [markdown]
# $$
# A_m = G_m~.~V_x~~\to~~V_x = \frac{A_m}{G_m} = \frac{19~V}{7,5}~~\to~~V_x = 2,53~V
# $$
